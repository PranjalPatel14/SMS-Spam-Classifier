# %%
import numpy as np
import pandas as pd

# %%
encodings = ['utf-8','latin1','ISO-8859-1','cp1252']
file_path = 'spam.csv'
#Attempts to read file using different Encodings
for encoding in encodings:
    try:
        df = pd.read_csv(file_path,encoding=encoding)
        print(f"File successfully read with encoding: {encoding}")
        break
    except UnicodeDecodeError:
        print(f"Failed to read with Encoding: {encoding}")
        continue
if 'df' in locals():
    print("CSV file has been successfully loaded.")
else:
    print("All encoding attempt failed. Unable to read the CSV File.")
# Out:
# Failed to read with Encoding: utf-8
# File successfully read with encoding: latin1
# CSV file has been successfully loaded.

# %%
df.sample(10)
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 2494   ham  You at mu? You should try to figure out how mu...        NaN
# 1308   ham   I jokin oni lar.. ÌÏ busy then i wun disturb Ì_.        NaN
# 1514   ham                       K:)all the best:)congrats...        NaN
# 3889  spam  Double Mins & 1000 txts on Orange tariffs. Lat...        NaN
# 3452   ham  Nowadays people are notixiquating the laxinorf...        NaN
# 455    ham    Si si. I think ill go make those oreo truffles.        NaN
# 470   spam  okmail: Dear Dave this is your final notice to...        NaN
# 2930   ham                     Hi' Test on  &lt;#&gt; rd ....        NaN
# 744    ham    Men like shorter ladies. Gaze up into his eyes.        NaN
# 2099  spam  SMS SERVICES. for your inclusive text credits,...        NaN
#
#      Unnamed: 3 Unnamed: 4
# 2494        NaN        NaN
# 1308        NaN        NaN
# 1514        NaN        NaN
# 3889        NaN        NaN
# 3452        NaN        NaN
# 455         NaN        NaN
# 470         NaN        NaN
# 2930        NaN        NaN
# 744         NaN        NaN
# 2099        NaN        NaN
